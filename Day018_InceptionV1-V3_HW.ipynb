# %% [markdown]
# ## 『本次練習內容』
# #### 學習如何搭建Inception Block

# %% [markdown]
# ## 『本次練習目的』
#   #### 了解Inception原理
#   #### 了解如何導入Inception block到原本架構中

# %% [markdown]
# ---

# %% [markdown]
# ![Incpeiton](Inception.png)

# %%
import numpy as np
import tensorflow
from keras.models import Model
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras import backend as K
from keras import layers
from keras.layers import BatchNormalization
from keras.layers import Activation

# %% [markdown]
# ## 導入InceptionV2-有BatchNormalization的Convolution

# %%
def Conv2d_bn(x,filters,kernel_size,padding='same',strides=(1, 1),normalizer=True,activation='relu',name=None):
    if name is not None:
        conv_name = name + '_conv'
        bn_name = name + '_bn'
        act_name = name + '_act'
    else:
        conv_name = None
        bn_name = None
        act_name = None
    bn_axis = 1 if K.image_data_format() == 'channels_first' else 3 
    # channel_first 表示input data的shape為(BATCH_NUMBER, CHANNEL, IMG_HEiGHT, IMG_WIDTH)
    # channel_last 表示input data的shape為(BATCH_NUMBER, IMG_HEiGHT, IMG_WIDTH, CHANNEL)
    
    x = Conv2D(
            filters, kernel_size,
            strides=strides, padding=padding,
            use_bias=False, name=conv_name)(x)
    if normalizer:
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    if activation:
        x = Activation(activation, name=act_name)(x)
    return x

# %% [markdown]
# ## 參考上圖搭建 InceptionV1_block

# %%
def InceptionV1_block(x, specs,channel_axis, name):
    (br0, br1, br2, br3) = specs   # ((64,), (96,128), (16,32), (32,))
    branch_0 = Conv2d_bn(x, br0[0], (1, 1), name=name+"_Branch_0")

    branch_1 = Conv2d_bn(x, br1[0], (1, 1), name=name+"_Branch_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (3, 3), name=name+"_Branch_1_1")

    '''Branch_2'''
    branch_2 = Conv2d_bn(x, br2[0], (1, 1), name=name+"_Branch_2")
    branch_2 = Conv2d_bn(branch_1, br2[1], (3, 3), name=name+"_Branch_2_1")
    
    '''Branch_3'''
    branch_3 = MaxPooling2D(pool_size=3, strides=(1,1), padding="same", name=name+"_Branch_3")(x)
    branch_3 = Conv2d_bn(branch_3, br3[0], (1, 1), name=name+"_Branch_3_1")

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name=name+"_Concatenated")
    return x

# %% [markdown]
# ## 測試

# %%
img_input = Input(shape=(224,224,1))
specs = ((64,), (96,128), (16,32), (32,))
x=InceptionV1_block(x=img_input, specs=specs, channel_axis=3, name='Block_1')
print(x)
# Out:
# Tensor("Block_1_Concatenated/concat:0", shape=(None, 224, 224, 256), dtype=float32)

# %% [markdown]
# ## 將 InceptionV1_block中n*n卷積改為1 x n+n x 1

# %%
def InceptionV3_block(x, specs,channel_axis, name):
    (br0, br1, br2, br3) = specs   # ((64,), (96,128), (16,32), (32,))
    branch_0 = Conv2d_bn(x, br0[0], (1, 1), name=name+"_Branch_0")

    branch_1 = Conv2d_bn(x, br1[0], (1, 1), name=name+"_Branch_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (1, 3), name=name+"_Branch_1_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (3, 1), name=name+"_Branch_1_2")

    '''Branch_2'''
    branch_2 = Conv2d_bn(x, br2[0], (1, 1), name=name+"_Branch_2")
    branch_2 = Conv2d_bn(branch_1, br2[1], (1, 3), name=name+"_Branch_2_1")
    branch_2 = Conv2d_bn(branch_1, br2[1], (3, 1), name=name+"_Branch_2_2")

    '''Branch_3'''
    branch_3 = MaxPooling2D(pool_size=3, strides=(1,1), padding="same", name=name+"_Branch_3")(x)
    branch_3 = Conv2d_bn(branch_3, br3[0], (1, 1), name=name+"_Branch_3_1")

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name=name+"_Concatenated")
    return x

# %% [markdown]
# ## 測試

# %%
img_input = Input(shape=(224,224,1))
x=InceptionV3_block(img_input, ((64,), (96,128), (16,32), (32,)), 3, 'Block_1')
print(x)
# Out:
# Tensor("Block_1_Concatenated/concat_1:0", shape=(None, 224, 224, 256), dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ## 額外練習

# %% [markdown]
# ## 將VGG16 Block_3中的Convolution全部改為InceptionV1_block
# ## Block_5中的Convolution全部改為InceptionV3_block
# ## 並將所有Convolution改為Conv2d_bn

# %% [markdown]
# #### 原vgg16架構

# %%
def VGG16(include_top=True,input_tensor=None, input_shape=(224,224,1),
          pooling='max',classes=1000):
 
    img_input = Input(shape=input_shape)

    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    if include_top:
        # Classification block
        x = Flatten(name='flatten')(x)
        x = Dense(4096, activation='relu', name='fc1')(x)
        x = Dense(4096, activation='relu', name='fc2')(x)
        x = Dense(classes, activation='softmax', name='predictions')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)

    inputs = img_input
    # Create model.
    model = Model(inputs, x, name='vgg16')

   
    return model

# %% [markdown]
# #### 修改後

# %%
def VGG16_Inception(include_top=True,input_tensor=None, input_shape=(224,224,1),
          pooling='max',classes=1000):
 
    img_input = Input(shape=input_shape)
    x = Conv2d_bn(img_input,64, (3, 3), activation='relu', padding='same', name='block1_conv1')
    x = Conv2d_bn(x,64, (3, 3), activation='relu', padding='same', name='block1_conv2')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2d_bn(x,128, (3, 3), activation='relu', padding='same', name='block2_conv1')
    x = Conv2d_bn(x,128, (3, 3), activation='relu', padding='same', name='block2_conv2')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    specs = ((64,), (96,128), (16,32), (32,)) #def InceptionV1_block(x, specs,channel_axis, name):
    x = InceptionV1_block(x, specs=specs, channel_axis=3, name='Inception_V1_1' )
    x = InceptionV1_block(x, specs=specs, channel_axis=3, name='Inception_V1_2' )
    x = InceptionV1_block(x, specs=specs, channel_axis=3, name='Inception_V1_3' )

    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2d_bn(x,512, (3, 3), activation='relu', padding='same', name='block4_conv1')
    x = Conv2d_bn(x,512, (3, 3), activation='relu', padding='same', name='block4_conv2')
    x = Conv2d_bn(x,512, (3, 3), activation='relu', padding='same', name='block4_conv3')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    #specs = ((64,), (96,128), (16,32), (32,))   # def InceptionV3_block(x, specs,channel_axis, name):
    x = InceptionV3_block(x, specs=specs, channel_axis=3, name="InceptionV3_block_1")
    x = InceptionV3_block(x, specs=specs, channel_axis=3, name="InceptionV3_block_2")
    x = InceptionV3_block(x, specs=specs, channel_axis=3, name="InceptionV3_block_3")
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    if include_top:
        # Classification block
        x = Flatten(name='flatten')(x)
        x = Dense(4096, activation='relu', name='fc1')(x)
        x = Dense(4096, activation='relu', name='fc2')(x)
        x = Dense(classes, activation='softmax', name='predictions')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)

    inputs = img_input
    # Create model.
    model = Model(inputs, x, name='vgg16_Inception')
   
    return model

# %%
model = VGG16_Inception(include_top=False)

# %%
model.summary()
# Out:
# Model: "vgg16_Inception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 1) 0
# __________________________________________________________________________________________________
# block1_conv1_conv (Conv2D)      (None, 224, 224, 64) 576         input_3[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 224, 224, 64) 192         block1_conv1_conv[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 224, 224, 64) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2_conv (Conv2D)      (None, 224, 224, 64) 36864       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 224, 224, 64) 192         block1_conv2_conv[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 224, 224, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1_conv (Conv2D)      (None, 112, 112, 128 73728       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 112, 112, 128 384         block2_conv1_conv[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (Activation)   (None, 112, 112, 128 0           block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2_conv (Conv2D)      (None, 112, 112, 128 147456      block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 112, 112, 128 384         block2_conv2_conv[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (Activation)   (None, 112, 112, 128 0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_1_conv (C (None, 56, 56, 96)   12288       block2_pool[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_1_bn (Bat (None, 56, 56, 96)   288         Inception_V1_1_Branch_1_conv[0][0
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_1_act (Ac (None, 56, 56, 96)   0           Inception_V1_1_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_1_1_conv  (None, 56, 56, 128)  110592      Inception_V1_1_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_1_1_bn (B (None, 56, 56, 128)  384         Inception_V1_1_Branch_1_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_1_1_act ( (None, 56, 56, 128)  0           Inception_V1_1_Branch_1_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_3 (MaxPoo (None, 56, 56, 128)  0           block2_pool[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_0_conv (C (None, 56, 56, 64)   8192        block2_pool[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_2_1_conv  (None, 56, 56, 32)   36864       Inception_V1_1_Branch_1_1_act[0][
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_3_1_conv  (None, 56, 56, 32)   4096        Inception_V1_1_Branch_3[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_0_bn (Bat (None, 56, 56, 64)   192         Inception_V1_1_Branch_0_conv[0][0
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_2_1_bn (B (None, 56, 56, 32)   96          Inception_V1_1_Branch_2_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_3_1_bn (B (None, 56, 56, 32)   96          Inception_V1_1_Branch_3_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_0_act (Ac (None, 56, 56, 64)   0           Inception_V1_1_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_2_1_act ( (None, 56, 56, 32)   0           Inception_V1_1_Branch_2_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_1_Branch_3_1_act ( (None, 56, 56, 32)   0           Inception_V1_1_Branch_3_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_1_Concatenated (Co (None, 56, 56, 256)  0           Inception_V1_1_Branch_0_act[0][0]
#                                                                  Inception_V1_1_Branch_1_1_act[0][
#                                                                  Inception_V1_1_Branch_2_1_act[0][
#                                                                  Inception_V1_1_Branch_3_1_act[0][
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_1_conv (C (None, 56, 56, 96)   24576       Inception_V1_1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_1_bn (Bat (None, 56, 56, 96)   288         Inception_V1_2_Branch_1_conv[0][0
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_1_act (Ac (None, 56, 56, 96)   0           Inception_V1_2_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_1_1_conv  (None, 56, 56, 128)  110592      Inception_V1_2_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_1_1_bn (B (None, 56, 56, 128)  384         Inception_V1_2_Branch_1_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_1_1_act ( (None, 56, 56, 128)  0           Inception_V1_2_Branch_1_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_3 (MaxPoo (None, 56, 56, 256)  0           Inception_V1_1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_0_conv (C (None, 56, 56, 64)   16384       Inception_V1_1_Concatenated[0][0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_2_1_conv  (None, 56, 56, 32)   36864       Inception_V1_2_Branch_1_1_act[0][
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_3_1_conv  (None, 56, 56, 32)   8192        Inception_V1_2_Branch_3[0][0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_0_bn (Bat (None, 56, 56, 64)   192         Inception_V1_2_Branch_0_conv[0][0
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_2_1_bn (B (None, 56, 56, 32)   96          Inception_V1_2_Branch_2_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_3_1_bn (B (None, 56, 56, 32)   96          Inception_V1_2_Branch_3_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_0_act (Ac (None, 56, 56, 64)   0           Inception_V1_2_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_2_1_act ( (None, 56, 56, 32)   0           Inception_V1_2_Branch_2_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_2_Branch_3_1_act ( (None, 56, 56, 32)   0           Inception_V1_2_Branch_3_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_2_Concatenated (Co (None, 56, 56, 256)  0           Inception_V1_2_Branch_0_act[0][0]
#                                                                  Inception_V1_2_Branch_1_1_act[0][
#                                                                  Inception_V1_2_Branch_2_1_act[0][
#                                                                  Inception_V1_2_Branch_3_1_act[0][
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_1_conv (C (None, 56, 56, 96)   24576       Inception_V1_2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_1_bn (Bat (None, 56, 56, 96)   288         Inception_V1_3_Branch_1_conv[0][0
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_1_act (Ac (None, 56, 56, 96)   0           Inception_V1_3_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_1_1_conv  (None, 56, 56, 128)  110592      Inception_V1_3_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_1_1_bn (B (None, 56, 56, 128)  384         Inception_V1_3_Branch_1_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_1_1_act ( (None, 56, 56, 128)  0           Inception_V1_3_Branch_1_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_3 (MaxPoo (None, 56, 56, 256)  0           Inception_V1_2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_0_conv (C (None, 56, 56, 64)   16384       Inception_V1_2_Concatenated[0][0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_2_1_conv  (None, 56, 56, 32)   36864       Inception_V1_3_Branch_1_1_act[0][
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_3_1_conv  (None, 56, 56, 32)   8192        Inception_V1_3_Branch_3[0][0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_0_bn (Bat (None, 56, 56, 64)   192         Inception_V1_3_Branch_0_conv[0][0
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_2_1_bn (B (None, 56, 56, 32)   96          Inception_V1_3_Branch_2_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_3_1_bn (B (None, 56, 56, 32)   96          Inception_V1_3_Branch_3_1_conv[0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_0_act (Ac (None, 56, 56, 64)   0           Inception_V1_3_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_2_1_act ( (None, 56, 56, 32)   0           Inception_V1_3_Branch_2_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_3_Branch_3_1_act ( (None, 56, 56, 32)   0           Inception_V1_3_Branch_3_1_bn[0][0
# __________________________________________________________________________________________________
# Inception_V1_3_Concatenated (Co (None, 56, 56, 256)  0           Inception_V1_3_Branch_0_act[0][0]
#                                                                  Inception_V1_3_Branch_1_1_act[0][
#                                                                  Inception_V1_3_Branch_2_1_act[0][
#                                                                  Inception_V1_3_Branch_3_1_act[0][
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           Inception_V1_3_Concatenated[0][0]
# __________________________________________________________________________________________________
# block4_conv1_conv (Conv2D)      (None, 28, 28, 512)  1179648     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv1_bn (BatchNormaliza (None, 28, 28, 512)  1536        block4_conv1_conv[0][0]
# __________________________________________________________________________________________________
# block4_conv1_act (Activation)   (None, 28, 28, 512)  0           block4_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_conv2_conv (Conv2D)      (None, 28, 28, 512)  2359296     block4_conv1_act[0][0]
# __________________________________________________________________________________________________
# block4_conv2_bn (BatchNormaliza (None, 28, 28, 512)  1536        block4_conv2_conv[0][0]
# __________________________________________________________________________________________________
# block4_conv2_act (Activation)   (None, 28, 28, 512)  0           block4_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block4_conv3_conv (Conv2D)      (None, 28, 28, 512)  2359296     block4_conv2_act[0][0]
# __________________________________________________________________________________________________
# block4_conv3_bn (BatchNormaliza (None, 28, 28, 512)  1536        block4_conv3_conv[0][0]
# __________________________________________________________________________________________________
# block4_conv3_act (Activation)   (None, 28, 28, 512)  0           block4_conv3_bn[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3_act[0][0]
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_co (None, 14, 14, 96)   49152       block4_pool[0][0]
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_bn (None, 14, 14, 96)   288         InceptionV3_block_1_Branch_1_conv
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_ac (None, 14, 14, 96)   0           InceptionV3_block_1_Branch_1_bn[0
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_1_ (None, 14, 14, 128)  36864       InceptionV3_block_1_Branch_1_act[
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_1_ (None, 14, 14, 128)  384         InceptionV3_block_1_Branch_1_1_co
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_1_ (None, 14, 14, 128)  0           InceptionV3_block_1_Branch_1_1_bn
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_2_ (None, 14, 14, 128)  49152       InceptionV3_block_1_Branch_1_1_ac
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_2_ (None, 14, 14, 128)  384         InceptionV3_block_1_Branch_1_2_co
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_1_2_ (None, 14, 14, 128)  0           InceptionV3_block_1_Branch_1_2_bn
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_3 (M (None, 14, 14, 512)  0           block4_pool[0][0]
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_0_co (None, 14, 14, 64)   32768       block4_pool[0][0]
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_2_2_ (None, 14, 14, 32)   12288       InceptionV3_block_1_Branch_1_2_ac
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_3_1_ (None, 14, 14, 32)   16384       InceptionV3_block_1_Branch_3[0][0
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_0_bn (None, 14, 14, 64)   192         InceptionV3_block_1_Branch_0_conv
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_2_2_ (None, 14, 14, 32)   96          InceptionV3_block_1_Branch_2_2_co
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_3_1_ (None, 14, 14, 32)   96          InceptionV3_block_1_Branch_3_1_co
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_0_ac (None, 14, 14, 64)   0           InceptionV3_block_1_Branch_0_bn[0
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_2_2_ (None, 14, 14, 32)   0           InceptionV3_block_1_Branch_2_2_bn
# __________________________________________________________________________________________________
# InceptionV3_block_1_Branch_3_1_ (None, 14, 14, 32)   0           InceptionV3_block_1_Branch_3_1_bn
# __________________________________________________________________________________________________
# InceptionV3_block_1_Concatenate (None, 14, 14, 256)  0           InceptionV3_block_1_Branch_0_act[
#                                                                  InceptionV3_block_1_Branch_1_2_ac
#                                                                  InceptionV3_block_1_Branch_2_2_ac
#                                                                  InceptionV3_block_1_Branch_3_1_ac
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_co (None, 14, 14, 96)   24576       InceptionV3_block_1_Concatenated[
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_bn (None, 14, 14, 96)   288         InceptionV3_block_2_Branch_1_conv
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_ac (None, 14, 14, 96)   0           InceptionV3_block_2_Branch_1_bn[0
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_1_ (None, 14, 14, 128)  36864       InceptionV3_block_2_Branch_1_act[
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_1_ (None, 14, 14, 128)  384         InceptionV3_block_2_Branch_1_1_co
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_1_ (None, 14, 14, 128)  0           InceptionV3_block_2_Branch_1_1_bn
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_2_ (None, 14, 14, 128)  49152       InceptionV3_block_2_Branch_1_1_ac
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_2_ (None, 14, 14, 128)  384         InceptionV3_block_2_Branch_1_2_co
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_1_2_ (None, 14, 14, 128)  0           InceptionV3_block_2_Branch_1_2_bn
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_3 (M (None, 14, 14, 256)  0           InceptionV3_block_1_Concatenated[
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_0_co (None, 14, 14, 64)   16384       InceptionV3_block_1_Concatenated[
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_2_2_ (None, 14, 14, 32)   12288       InceptionV3_block_2_Branch_1_2_ac
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_3_1_ (None, 14, 14, 32)   8192        InceptionV3_block_2_Branch_3[0][0
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_0_bn (None, 14, 14, 64)   192         InceptionV3_block_2_Branch_0_conv
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_2_2_ (None, 14, 14, 32)   96          InceptionV3_block_2_Branch_2_2_co
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_3_1_ (None, 14, 14, 32)   96          InceptionV3_block_2_Branch_3_1_co
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_0_ac (None, 14, 14, 64)   0           InceptionV3_block_2_Branch_0_bn[0
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_2_2_ (None, 14, 14, 32)   0           InceptionV3_block_2_Branch_2_2_bn
# __________________________________________________________________________________________________
# InceptionV3_block_2_Branch_3_1_ (None, 14, 14, 32)   0           InceptionV3_block_2_Branch_3_1_bn
# __________________________________________________________________________________________________
# InceptionV3_block_2_Concatenate (None, 14, 14, 256)  0           InceptionV3_block_2_Branch_0_act[
#                                                                  InceptionV3_block_2_Branch_1_2_ac
#                                                                  InceptionV3_block_2_Branch_2_2_ac
#                                                                  InceptionV3_block_2_Branch_3_1_ac
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_co (None, 14, 14, 96)   24576       InceptionV3_block_2_Concatenated[
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_bn (None, 14, 14, 96)   288         InceptionV3_block_3_Branch_1_conv
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_ac (None, 14, 14, 96)   0           InceptionV3_block_3_Branch_1_bn[0
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_1_ (None, 14, 14, 128)  36864       InceptionV3_block_3_Branch_1_act[
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_1_ (None, 14, 14, 128)  384         InceptionV3_block_3_Branch_1_1_co
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_1_ (None, 14, 14, 128)  0           InceptionV3_block_3_Branch_1_1_bn
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_2_ (None, 14, 14, 128)  49152       InceptionV3_block_3_Branch_1_1_ac
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_2_ (None, 14, 14, 128)  384         InceptionV3_block_3_Branch_1_2_co
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_1_2_ (None, 14, 14, 128)  0           InceptionV3_block_3_Branch_1_2_bn
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_3 (M (None, 14, 14, 256)  0           InceptionV3_block_2_Concatenated[
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_0_co (None, 14, 14, 64)   16384       InceptionV3_block_2_Concatenated[
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_2_2_ (None, 14, 14, 32)   12288       InceptionV3_block_3_Branch_1_2_ac
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_3_1_ (None, 14, 14, 32)   8192        InceptionV3_block_3_Branch_3[0][0
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_0_bn (None, 14, 14, 64)   192         InceptionV3_block_3_Branch_0_conv
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_2_2_ (None, 14, 14, 32)   96          InceptionV3_block_3_Branch_2_2_co
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_3_1_ (None, 14, 14, 32)   96          InceptionV3_block_3_Branch_3_1_co
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_0_ac (None, 14, 14, 64)   0           InceptionV3_block_3_Branch_0_bn[0
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_2_2_ (None, 14, 14, 32)   0           InceptionV3_block_3_Branch_2_2_bn
# __________________________________________________________________________________________________
# InceptionV3_block_3_Branch_3_1_ (None, 14, 14, 32)   0           InceptionV3_block_3_Branch_3_1_bn
# __________________________________________________________________________________________________
# InceptionV3_block_3_Concatenate (None, 14, 14, 256)  0           InceptionV3_block_3_Branch_0_act[
#                                                                  InceptionV3_block_3_Branch_1_2_ac
#                                                                  InceptionV3_block_3_Branch_2_2_ac
#                                                                  InceptionV3_block_3_Branch_3_1_ac
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 256)    0           InceptionV3_block_3_Concatenated[
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 256)          0           block5_pool[0][0]
# ==================================================================================================
# Total params: 7,226,880
# Trainable params: 7,218,048
# Non-trainable params: 8,832
# __________________________________________________________________________________________________
